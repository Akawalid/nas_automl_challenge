# %%
import sys
if "../" not in sys.path:
    sys.path.append("../")

# %%
import os
os.chdir("/home/tau/sdouka/codebase/experimental_grow")
os.getcwd()
# Out:
# '/home/tau/sdouka/codebase/experimental_grow'

# %%
from tools.logger import Logger

# %%
logger = Logger(experiment_name="HSICv2")
logger

# %%
logger.start_run(run_id="")
logger.end_run()
# Out:
# 2025/06/19 18:38:36 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/06/19 18:38:36 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/06/19 18:38:39 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
